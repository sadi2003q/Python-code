# %%
import pandas as pd
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
bill = pd.read_csv('Bill.csv')
fuel = pd.read_csv('Fuel.csv')

# %% [markdown]
# # Scatterplot (Numerical - Numerical)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
fuel.head()
# Out:
#    Year   MAKE    MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 0  2000  ACURA    1.6EL       COMPACT          1.6          4           A4
# 1  2000  ACURA    1.6EL       COMPACT          1.6          4           M5
# 2  2000  ACURA    3.2TL      MID-SIZE          3.2          6          AS5
# 3  2000  ACURA    3.5RL      MID-SIZE          3.5          6           A4
# 4  2000  ACURA  INTEGRA    SUBCOMPACT          1.8          4           A4
#
#   FUEL  FUEL CONSUMPTION  COEMISSIONS
# 0    X              10.5           216
# 1    X               9.8           205
# 2    Z              13.7           265
# 3    Z              15.0           301
# 4    X              11.4           230

# %%
bill.head()
# Out:
#    num_rooms  num_people  housearea  is_ac  is_tv  is_flat  \
# 0          3           3     742.57      1      1        1
# 1          1           5     952.99      0      1        0
# 2          3           1     761.44      1      1        1
# 3          0           5     861.32      1      1        0
# 4          1           8     731.61      0      1        0
#
#    ave_monthly_income  num_children  is_urban  amount_paid
# 0             9675.93             2         0   560.481447
# 1            35064.79             1         1   633.283679
# 2            22292.44             0         0   511.879157
# 3            12139.08             0         0   332.992035
# 4            17230.10             2         1   658.285625

# %%
sns.scatterplot(x=bill['ave_monthly_income'], y=bill['amount_paid'], hue=bill['is_ac'], style=bill['num_children'], size= bill['num_people'])
# Out:
# <Axes: xlabel='ave_monthly_income', ylabel='amount_paid'>

# %%
sns.barplot(x=fuel['FUEL'], y=fuel['FUEL CONSUMPTION'], hue=fuel['VEHICLE CLASS'])
# Out:
# <Axes: xlabel='FUEL', ylabel='FUEL CONSUMPTION'>

# %% [markdown]
# # Box plotting

# %%
sns.boxplot(x=train['Survived'], y= train['Age'], hue=train['Sex'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# # Dist plotting

# %%
sns.distplot(train[train['Survived']==1]['Age'],hist = False)
sns.distplot(train[train['Survived']==0]['Age'], hist = False)
# Out:
# /var/folders/c4/g4th1y192hlgglxhh6s94n8m0000gn/T/ipykernel_5045/1324388745.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train[train['Survived']==1]['Age'],hist = False)
# /var/folders/c4/g4th1y192hlgglxhh6s94n8m0000gn/T/ipykernel_5045/1324388745.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(train[train['Sex']=='male']['Survived'],  hist = False)
sns.distplot(train[train['Sex']=='female']['Survived'],  hist = False)
# Out:
# /var/folders/c4/g4th1y192hlgglxhh6s94n8m0000gn/T/ipykernel_5045/603820406.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train[train['Sex']=='male']['Survived'],  hist = False)
# /var/folders/c4/g4th1y192hlgglxhh6s94n8m0000gn/T/ipykernel_5045/603820406.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # heat Map

# %%
heat_map = pd.crosstab(train['Pclass'], train['Survived'])
sns.heatmap(heat_map)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
heat_map
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
engine_consumption = pd.crosstab(fuel['VEHICLE CLASS'], fuel['FUEL CONSUMPTION'])
engine_consumption
# Out:
# FUEL CONSUMPTION          4.9   6.7   7.1   7.6   8.1   8.2   8.6   8.7   \
# VEHICLE CLASS
# COMPACT                      0     2     0     0     2     1     1     1
# FULL-SIZE                    0     0     0     0     0     0     0     0
# MID-SIZE                     0     0     0     0     0     0     0     0
# MINICOMPACT                  0     0     0     0     0     0     0     0
# MINIVAN                      0     0     0     0     0     0     0     0
# PICKUP TRUCK - SMALL         0     0     0     0     0     0     0     0
# PICKUP TRUCK - STANDARD      0     0     0     0     0     0     0     0
# STATION WAGON - MID-SIZE     0     0     0     0     0     0     0     0
# STATION WAGON - SMALL        0     0     0     0     0     0     0     0
# SUBCOMPACT                   1     1     2     3     1     0     0     0
# SUV                          0     0     0     0     0     0     0     0
# TWO-SEATER                   0     0     0     0     0     0     0     0
# ...

# %% [markdown]
# # Cluster Map

# %%
sns.clustermap(pd.crosstab(train['Pclass'], train['Survived']))

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(train, hue='Fare')

# %% [markdown]
# # Line Plot

# %%
sns.lineplot(x=bill['num_people'], y=bill['ave_monthly_income'])
# Out:
# <Axes: xlabel='num_people', ylabel='ave_monthly_income'>
