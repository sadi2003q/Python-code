# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('orders.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
df['year'] = df['date'].dt.year

# %%
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day

# %%
df['month Name'] = df['date'].dt.month_name()
df['week day'] = df['date'].dt.dayofweek
df['day Name'] = df['date'].dt.day_name()

# %%
df['Is Weekend'] = np.where(df['day Name'].isin(['Friday']), 1, 0)
df['Quarter number'] = df['date'].dt.quarter

# %%
df.sample(10)
# Out:
#           date  product_id  city_id  orders  year  month  day month Name  \
# 143 2018-08-09        5284       25       8  2018      8    9     August
# 428 2018-07-14        4183       22       8  2018      7   14       July
# 680 2019-11-17        4111       18       2  2019     11   17   November
# 589 2019-01-02        1757       26       1  2019      1    2    January
# 576 2019-10-11         202        2       3  2019     10   11    October
# 660 2019-04-01        6599       23       1  2019      4    1      April
# 847 2019-08-17        6253       30       1  2019      8   17     August
# 437 2019-08-04        2830       14      21  2019      8    4     August
# 787 2019-07-19        5371       22       8  2019      7   19       July
# 628 2019-08-03        5823       27       1  2019      8    3     August
#
#      week day   day Name  Is Weekend  Quarter number
# 143         3   Thursday           0               3
# 428         5   Saturday           0               3
# 680         6     Sunday           0               4
# 589         2  Wednesday           0               1
# 576         4     Friday           1               4
# 660         0     Monday           0               2
# 847         5   Saturday           0               3
# 437         6     Sunday           0               3
# 787         4     Friday           1               3
# 628         5   Saturday           0               3

# %%
import datetime

# %%
df = pd.read_csv('messages.csv')

# %%
df.sample(10)
# Out:
#                     date                                                msg
# 544  2015-01-14 00:17:00  Андрюшка  я люблю тебя больше всех! Ты удивите...
# 197  2014-02-03 22:55:00            М 44 ИЩУ СТРОЙНУЮ ПОСЛУШНУЮ  0638944582
# 388  2014-08-01 22:32:00        я все нормально мне дали 3 6 уже с ув. Ухо.
# 588  2012-05-03 01:16:00  симп паре 25лет поз с милой девушкой с/о 093 9...
# 429  2012-06-13 00:35:00  п 30л познакомлюсь с девушкой для встречь 0988...
# 727  2012-06-09 01:23:00  Користувач Гicть проголосував ЗА кліп Центр — ...
# 696  2016-09-23 00:23:00                              для\tОльги 0684607724
# 612  2012-10-30 01:22:00                        Лора  нельзя так ТУПИТЬ!!!!
# 841  2012-08-08 00:12:00  П 31 покатаю красивую д ж без комплексов 067 9...
# 121  2013-12-09 01:09:00              холостяк хочет познакомится 40л богат

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute
df['second'] = df['date'].dt.second

# %%
df.sample(10)
# Out:
#                    date                                                msg  \
# 484 2012-06-02 23:47:00  ГОЛЬФ ПРИВ ПАПУЛЯ-РОДНУЛЯ.Я УЖЕ ДОМА.ЖАЛЬ ЧТО ...
# 715 2014-05-26 01:04:00    Парень фитнес модель 25лет встречусь.0990991317
# 796 2015-12-10 00:57:00       позн с сем парой для встреч 0501911095 днепр
# 839 2013-05-18 01:59:00  Самый дорогой подарок женщине... внимание. Пос...
# 764 2013-11-09 01:38:00  Девушки женщины пишите звоните пообщаемся встр...
# 746 2013-10-18 01:34:00  щедр  красив  умен и богат  на своем авто! Нуж...
# 308 2013-06-05 00:28:00                          Парни - заедим 0957640870
# 899 2013-01-14 01:38:00       симпатичный парень 23 ищет нескромну милашку
# 102 2015-09-05 00:58:00  м-39/170 ищу спо*ж..м..с.п снач смс 063 798 06 35
# 506 2015-02-14 23:04:00       парень ищет не скромную девушку 063 410 6482
#
#      hour  minute  second
# 484    23      47       0
# 715     1       4       0
# 796     0      57       0
# 839     1      59       0
# 764     1      38       0
# 746     1      34       0
# 308     0      28       0
# 899     1      38       0
# 102     0      58       0
# 506    23       4       0
